# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pickle
import pypcd

# %matplotlib notebook

# %%
pc = pypcd.PointCloud.from_path('../data/full_dataset_sample/trainEnv_0_185647000.pcd')

# %%
pc_full = pc.pc_data.copy()
print(len(pc_full['x']))
sub = 10
print(len(pc_full['x'][::sub]))
# Out:
# 307200
# 61440

# %%
pc_sub_x = pc_full['x'][::sub]
pc_sub_y = pc_full['y'][::sub]
pc_sub_z = pc_full['z'][::sub]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# ax = Axes3D(fig)
ax.scatter(pc.pc_data['x'], pc.pc_data['y'], pc.pc_data['z'], color='b')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111, projection='3d')
# ax = Axes3D(fig)
ax1.scatter(pc_sub_x, pc_sub_y, pc_sub_z, color='b')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
pc1 = pypcd.PointCloud.from_path('../data/full_dataset_sample/trainEnv_1_194647000.pcd')
pc2 = pypcd.PointCloud.from_path('../data/full_dataset_sample/trainEnv_2_203647000.pcd')
pc3 = pypcd.PointCloud.from_path('../data/full_dataset_sample/trainEnv_3_212648000.pcd')

# %%
fig1 = plt.figure()
ax = fig1.add_subplot(111, projection='3d')
# ax = Axes3D(fig)
ax.scatter(pc1.pc_data['x'], pc1.pc_data['y'], pc1.pc_data['z'], color='b', marker='.')
# Out:
# <img src="data:image/png;base64,...">

# %%
print(pc.pc_data['x'].shape)
print(pc1.pc_data['x'].shape)
print(pc2.pc_data['x'].shape)
print(pc3.pc_data['x'].shape)
# Out:
# (307200,)
# (307200,)
# (307200,)
# (307200,)

# %%
temp = np.zeros((3, pc.pc_data['x'].shape[0]))

temp[0] = pc.pc_data['x']
temp[1] = pc.pc_data['y']
temp[2] = pc.pc_data['z']

# %%
print(temp.shape)

print(temp.flatten('F').shape)

print(np.isfinite(temp.flatten('F')))
print(np.where(np.isfinite(temp.flatten('F')))[:18])
print(np.where(np.isfinite(temp))[:6])

inds = np.where(np.isfinite(temp.flatten('F')))[0][:18]
inds_0 = np.where(np.isfinite(temp))[0][:6]
inds_1 = np.where(np.isfinite(temp))[1][:6]
# Out:
# (3, 307200)
# (921600,)
# [False False False ..., False False False]
# (array([651945, 651946, 651947, ..., 921018, 921019, 921020]),)
# (array([0, 0, 0, ..., 2, 2, 2]), array([217315, 217316, 217317, ..., 307004, 307005, 307006]))

# %%
for i in range(0, inds.shape[0], 3):
    print(temp.flatten('F')[inds[i]], temp.flatten('F')[inds[i+1]], temp.flatten('F')[inds[i+2]])

# for i in range():
#     print(temp[inds1[0][i], inds1[1][i]])
# Out:
# (0.51620948314666748, 1.4468406438827515, 2.9877569675445557)
# (0.53075069189071655, 1.4468408823013306, 2.9877574443817139)
# (0.54529190063476562, 1.4468412399291992, 2.9877581596374512)
# (0.5598331093788147, 1.4468414783477783, 2.9877586364746094)
# (0.57437425851821899, 1.4468414783477783, 2.9877586364746094)
# (0.58891540765762329, 1.4468415975570679, 2.9877588748931885)

# %%
start = 100000
range = 5
end = start + range
end1 = start + range*3

print(temp[:, start:end])

print(temp.flatten()[start:end1])`

# %%
temp = np.zeros((3, pc.pc_data['x'].shape[0]))

temp[0] = pc.pc_data['x']
temp[1] = pc.pc_data['y']
temp[2] = pc.pc_data['z']

temp1 = np.zeros((3, pc1.pc_data['x'].shape[0]))

temp1[0] = pc1.pc_data['x']
temp1[1] = pc1.pc_data['y']
temp1[2] = pc1.pc_data['z']

temp2 = np.zeros((3, pc2.pc_data['x'].shape[0]))

temp2[0] = pc2.pc_data['x']
temp2[1] = pc2.pc_data['y']
temp2[2] = pc2.pc_data['z']

# %%
flat0 = temp.flatten('F')
flat1 = temp1.flatten('F')
flat2 = temp2.flatten('F')

# %%
inds0 = np.where(np.isfinite(flat0))[0]
inds1 = np.where(np.isfinite(flat1))[0]
inds2 = np.where(np.isfinite(flat2))[0]

# %%
print(inds0.shape[0], inds1.shape[0], inds2.shape[0])
# Out:
# (41238, 41370, 41289)
